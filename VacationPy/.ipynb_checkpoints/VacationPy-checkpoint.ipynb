# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import csv
from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#1st try
csv_path = os.path.join("..", "output_data", "weather_data_500.csv")

weather_data_500cities_df = pd.read_csv(csv_path)
weather_data_500cities_df
# Out:
#                 City  Latitude  Longitude  Max_Temp  Humidity  Cloudiness  \
# 0     guerrero negro  20.04980 -124.30876     76.55        59          42
# 1            aksaray  38.09462   34.08466     57.20        67          40
# 2           lokosovo  60.14940   74.18426     50.40        89          71
# 3          upernavik  76.18924  -57.14193     31.37        94          92
# 4             touros  -2.00498  -35.08715     73.40        78          20
# ...              ...       ...        ...       ...       ...         ...
# 1106        arrecife  29.07221  -13.03237     71.60        88           0
# 1107      chokurdakh  82.20418  145.36105     57.81        43          82
# 1108          avarua -47.11703 -166.41334     73.40        64          48
# 1109          hohhot  41.10209  112.27888     62.60        45           0
# 1110     belaya gora  68.16932  147.36603     58.44        37           3
#
#       Wind_Speed Country_Code
# 0          13.69           mx
# 1           3.36           tr
# 2           3.42           ru
# 3           4.18           gl
# 4           4.70           br
# ...          ...          ...
# 1106        8.05           es
# 1107        7.18           ru
# 1108       10.29           ck
# 1109        2.24           cn
# 1110       15.75           ru
#
# [1111 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# SET UP LAT LONG PAIRS
Coords1 = weather_data_500cities_df[['Latitude', 'Longitude']]

# Set up a list of humidities
Humidity = weather_data_500cities_df[['Humidity']]
HumidityList = Humidity.values.tolist()


# SET UP FRAMEWORK FOR API CALL
# Create base API url
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
location = "20.04980, 124.30876"
key = g_key

# # Dictionary to store query parameters
# params = {
#     "location": "20.04980, 124.30876", # coordinates for the city; guerrero negro
#     "key": g_key,
# }

# Build the endpoint URL
target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?latlng={location}&key={key}')

print(target_url)

# Run a request to endpoint and convert result to json
geo_data =  requests.get(target_url).json()
# Pretty Print the json
pprint(geo_data)

# CONFIGURE GMAPS
# gmaps.configure(api_key=g_key)

# # store the figure in a variable so we can continue to add layers to the same map
# fig = gmaps.figure()

# # Create a marker layer using our coordinates
# markers = gmaps.marker_layer(HumidityList)

# # Add the layer to the map
# fig.add_layer(markers)

# # display the figure with the newly added layer
# fig
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?latlng=20.04980, 124.30876&key=AIzaSyC-NMA8imX9gPlHXl6mh2Yh9pObSEMTVEs
# {'plus_code': {'global_code': '7QG628X5+WG'},
#  'results': [],
#  'status': 'ZERO_RESULTS'}

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
