# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.stats import sem
from scipy.stats import linregress
import os
import csv
import random
import numpy as np
import requests
from pprint import pprint
from config import api_key

# %% [markdown]
# ## Generate Cities List

# %%
### Generate a random Lat Long table to generate a cities list:  
latlist = []
longlist = []
for i in range(0,1500):
    latlist.append(float(random.randrange(-90, 90))*1.00249)
    longlist.append(float(random.randrange(-180, 180))*1.00249)

dict_with_lists = {"Latitude": latlist,
                   "Longitude": longlist}
RandomLatLong_df = pd.DataFrame(dict_with_lists)

# Make sure not lat long values above +/- 90 and +/- 180 respectively  
RandomLatLong_df = RandomLatLong_df.loc[(RandomLatLong_df["Longitude"]>=-180)]
RandomLatLong_df = RandomLatLong_df.loc[(RandomLatLong_df["Longitude"]<=180)]
RandomLatLong_df = RandomLatLong_df.loc[(RandomLatLong_df["Latitude"]>=-90)]
RandomLatLong_df = RandomLatLong_df.loc[(RandomLatLong_df["Latitude"]<=90)]

# View lat long dataframe
RandomLatLong_df
# Out:
#       Latitude  Longitude
# 0     23.05727   15.03735
# 1     -4.00996   57.14193
# 2     55.13695  -55.13695
# 3     -6.01494  163.40587
# 4    -26.06474  176.43824
# ...        ...        ...
# 1494 -42.10458   55.13695
# 1495 -26.06474 -158.39342
# 1497 -84.20916   39.09711
# 1498  86.21414   29.07221
# 1499  -1.00249 -101.25149
#
# [1488 rows x 2 columns]

# %%
### Generate a random cities from Lat Long table make sure we have up to 500. Delete any duplicates: 
# Make lists needed
cityList = []
countryList = []

# Create a loop to find a city for each lat long pair
for index, row in RandomLatLong_df.iterrows():
    print(f"Searching for nearest city to lat long {row['Latitude'], row['Longitude']}...")
    city = citipy.nearest_city(row["Latitude"], row["Longitude"])
    cityName = city.city_name
    cityCountry = city.country_code
    RandomLatLong_df.loc[index,"City_Name"] = cityName
    RandomLatLong_df.loc[index,"Country"] = cityCountry
    cityList.append(cityName)
    countryList.append(cityCountry)

### Trying to identify and remove any duplicate cities 
CleanLatLong_df = RandomLatLong_df.drop_duplicates(subset = ['City_Name'])
print(RandomLatLong_df["City_Name"].value_counts())
          
# Update my cities and country list and lat long lists
citySeries = CleanLatLong_df['City_Name']
countrySeries = CleanLatLong_df['Country']
LatSeries = CleanLatLong_df['Latitude']
LongSeries = CleanLatLong_df['Longitude']
cityList = citySeries.values.tolist()
countryList = countrySeries.values.tolist()
LatList = LatSeries.values.tolist()
LongList = LongSeries.values.tolist()

citySeries
# Out:
# Searching for nearest city to lat long (23.057270000000003, 15.037350000000002)...
# Searching for nearest city to lat long (-4.00996, 57.14193000000001)...
# Searching for nearest city to lat long (55.136950000000006, -55.136950000000006)...
# Searching for nearest city to lat long (-6.014940000000001, 163.40587000000002)...
# Searching for nearest city to lat long (-26.064740000000004, 176.43824)...
# Searching for nearest city to lat long (63.156870000000005, 100.24900000000001)...
# Searching for nearest city to lat long (-77.19173, 36.08964)...
# Searching for nearest city to lat long (-66.16434000000001, 93.23157)...
# Searching for nearest city to lat long (-47.11703000000001, -162.40338000000003)...
# Searching for nearest city to lat long (-55.136950000000006, -112.27888000000002)...
# Searching for nearest city to lat long (82.20418000000001, 130.3237)...
# Searching for nearest city to lat long (-85.21165, -168.41832000000002)...
# Searching for nearest city to lat long (-39.09711, -94.23406000000001)...
# Searching for nearest city to lat long (59.146910000000005, -68.16932000000001)...
# Searching for nearest city to lat long (56.13944000000001, -171.42579)...
# Searching for nearest city to lat long (-16.03984, 99.24651000000001)...
# Searching for nearest city to lat long (63.156870000000005, -139.34611)...
# Searching for nearest city to lat long (-80.1992, 0.0)...
# Searching for nearest city to lat long (58.144420000000004, -121.30129000000001)...
# Searching for nearest city to lat long (56.13944000000001, -144.35856)...
# Searching for nearest city to lat long (-74.18426000000001, -145.36105)...
# Searching for nearest city to lat long (-69.17181000000001, 129.32121)...
# Searching for nearest city to lat long (-12.029880000000002, -94.23406000000001)...
# Searching for nearest city to lat long (-80.1992, 4.00996)...
# Searching for nearest city to lat long (-18.04482, 18.04482)...
# Searching for nearest city to lat long (46.114540000000005, -89.22161000000001)...
# Searching for nearest city to lat long (36.08964, 120.29880000000001)...
# Searching for nearest city to lat long (34.08466000000001, -35.08715)...
# Searching for nearest city to lat long (80.1992, 139.34611)...
# Searching for nearest city to lat long (22.05478, -156.38844)...
# Searching for nearest city to lat long (64.15936, -11.02739)...
# Searching for nearest city to lat long (-41.102090000000004, 6.014940000000001)...
# Searching for nearest city to lat long (-60.14940000000001, -175.43575)...
# Searching for nearest city to lat long (-37.092130000000004, 160.3984)...
# Searching for nearest city to lat long (86.21414000000001, -33.082170000000005)...
# Searching for nearest city to lat long (-52.12948000000001, -20.0498)...
# Searching for nearest city to lat long (-71.17679000000001, -133.33117000000001)...
# Searching for nearest city to lat long (-82.20418000000001, -104.25896000000002)...
# Searching for nearest city to lat long (58.144420000000004, 13.032370000000002)...
# Searching for nearest city to lat long (-24.059760000000004, 3.0074700000000005)...
# Searching for nearest city to lat long (76.18924000000001, -79.19671000000001)...
# Searching for nearest city to lat long (42.104580000000006, -24.059760000000004)...
# Searching for nearest city to lat long (59.146910000000005, -1.00249)...
# Searching for nearest city to lat long (18.04482, 138.34362000000002)...
# Searching for nearest city to lat long (-28.069720000000004, -38.094620000000006)...
# Searching for nearest city to lat long (0.0, 163.40587000000002)...
# Searching for nearest city to lat long (75.18675, -2.00498)...
# Searching for nearest city to lat long (-9.02241, 41.102090000000004)...
# Searching for nearest city to lat long (15.037350000000002, 14.034860000000002)...
# Searching for nearest city to lat long (-59.146910000000005, -61.15189000000001)...
# Searching for nearest city to lat long (-47.11703000000001, -41.102090000000004)...
# Searching for nearest city to lat long (-53.13197, -138.34362000000002)...
# Searching for nearest city to lat long (-5.01245, 167.41583000000003)...
# Searching for nearest city to lat long (-61.15189000000001, -179.44571000000002)...
# Searching for nearest city to lat long (-52.12948000000001, -6.014940000000001)...
# Searching for nearest city to lat long (89.22161000000001, -73.18177000000001)...
# Searching for nearest city to lat long (-1.00249, -27.067230000000002)...
# Searching for nearest city to lat long (9.02241, -81.20169000000001)...
# Searching for nearest city to lat long (77.19173, -110.27390000000001)...
# Searching for nearest city to lat long (66.16434000000001, -101.25149)...
# Searching for nearest city to lat long (-8.01992, -147.36603000000002)...
# Searching for nearest city to lat long (-28.069720000000004, -175.43575)...
# Searching for nearest city to lat long (11.02739, 41.102090000000004)...
# Searching for nearest city to lat long (-25.062250000000002, 179.44571000000002)...
# Searching for nearest city to lat long (-11.02739, -1.00249)...
# Searching for nearest city to lat long (85.21165, 77.19173)...
# Searching for nearest city to lat long (48.11952000000001, 133.33117000000001)...
# Searching for nearest city to lat long (26.064740000000004, 157.39093000000003)...
# Searching for nearest city to lat long (78.19422, 4.00996)...
# Searching for nearest city to lat long (-5.01245, -112.27888000000002)...
# Searching for nearest city to lat long (18.04482, 49.12201)...
# Searching for nearest city to lat long (-59.146910000000005, 144.35856)...
# Searching for nearest city to lat long (48.11952000000001, -114.28386000000002)...
# Searching for nearest city to lat long (-83.20667, -122.30378000000002)...
# Searching for nearest city to lat long (53.13197, -165.41085)...
# Searching for nearest city to lat long (40.0996, 34.08466000000001)...
# Searching for nearest city to lat long (33.082170000000005, -52.12948000000001)...
# Searching for nearest city to lat long (-5.01245, 43.10707000000001)...
# Searching for nearest city to lat long (62.15438, -34.08466000000001)...
# Searching for nearest city to lat long (-58.144420000000004, 29.072210000000002)...
# Searching for nearest city to lat long (26.064740000000004, -21.052290000000003)...
# Searching for nearest city to lat long (2.00498, 42.104580000000006)...
# Searching for nearest city to lat long (-65.16185, -60.14940000000001)...
# Searching for nearest city to lat long (76.18924000000001, 136.33864000000003)...
# Searching for nearest city to lat long (-8.01992, 126.31374000000001)...
# Searching for nearest city to lat long (23.057270000000003, 38.094620000000006)...
# Searching for nearest city to lat long (-2.00498, -134.33366)...
# Searching for nearest city to lat long (47.11703000000001, 0.0)...
# Searching for nearest city to lat long (69.17181000000001, 113.28137000000001)...
# Searching for nearest city to lat long (30.074700000000004, 52.12948000000001)...
# Searching for nearest city to lat long (-22.05478, -158.39342000000002)...
# Searching for nearest city to lat long (-50.124500000000005, -108.26892000000001)...
# Searching for nearest city to lat long (81.20169000000001, 170.4233)...
# Searching for nearest city to lat long (-38.094620000000006, -166.41334)...
# Searching for nearest city to lat long (-74.18426000000001, 125.31125000000002)...
# Searching for nearest city to lat long (-78.19422, -145.36105)...
# Searching for nearest city to lat long (6.014940000000001, 159.39591000000001)...
# Searching for nearest city to lat long (7.017430000000001, 31.07719)...
# Searching for nearest city to lat long (82.20418000000001, -144.35856)...
# Searching for nearest city to lat long (-16.03984, 161.40089)...
# Searching for nearest city to lat long (-79.19671000000001, 100.24900000000001)...
# Searching for nearest city to lat long (-53.13197, 114.28386000000002)...
# Searching for nearest city to lat long (-18.04482, -114.28386000000002)...
# Searching for nearest city to lat long (61.15189000000001, 126.31374000000001)...
# Searching for nearest city to lat long (73.18177000000001, -137.34113000000002)...
# Searching for nearest city to lat long (0.0, -81.20169000000001)...
# Searching for nearest city to lat long (-80.1992, 22.05478)...
# Searching for nearest city to lat long (-66.16434000000001, -119.29631)...
# Searching for nearest city to lat long (35.08715, -127.31623000000002)...
# Searching for nearest city to lat long (69.17181000000001, 134.33366)...
# Searching for nearest city to lat long (63.156870000000005, 99.24651000000001)...
# Searching for nearest city to lat long (29.072210000000002, 56.13944000000001)...
# Searching for nearest city to lat long (-52.12948000000001, -115.28635000000001)...
# Searching for nearest city to lat long (-50.124500000000005, 1.00249)...
# Searching for nearest city to lat long (39.09711, 88.21912)...
# Searching for nearest city to lat long (-19.047310000000003, 26.064740000000004)...
# Searching for nearest city to lat long (-85.21165, 86.21414000000001)...
# Searching for nearest city to lat long (72.17928, -6.014940000000001)...
# Searching for nearest city to lat long (-84.20916000000001, 148.36852000000002)...
# Searching for nearest city to lat long (40.0996, -126.31374000000001)...
# Searching for nearest city to lat long (62.15438, 44.10956)...
# Searching for nearest city to lat long (-65.16185, -139.34611)...
# Searching for nearest city to lat long (-11.02739, 125.31125000000002)...
# Searching for nearest city to lat long (10.0249, 58.144420000000004)...
# Searching for nearest city to lat long (70.1743, -123.30627000000001)...
# Searching for nearest city to lat long (3.0074700000000005, -99.24651000000001)...
# Searching for nearest city to lat long (-77.19173, -103.25647000000001)...
# Searching for nearest city to lat long (22.05478, 85.21165)...
# Searching for nearest city to lat long (3.0074700000000005, -66.16434000000001)...
# Searching for nearest city to lat long (-77.19173, 115.28635000000001)...
# Searching for nearest city to lat long (35.08715, 97.24153000000001)...
# Searching for nearest city to lat long (-89.22161000000001, -153.38097000000002)...
# Searching for nearest city to lat long (-70.1743, 136.33864000000003)...
# Searching for nearest city to lat long (-46.114540000000005, 166.41334)...
# Searching for nearest city to lat long (-32.07968, -101.25149)...
# Searching for nearest city to lat long (-18.04482, 26.064740000000004)...
# Searching for nearest city to lat long (28.069720000000004, 89.22161000000001)...
# Searching for nearest city to lat long (-38.094620000000006, 163.40587000000002)...
# Searching for nearest city to lat long (-42.104580000000006, 160.3984)...
# Searching for nearest city to lat long (74.18426000000001, 22.05478)...
# Searching for nearest city to lat long (89.22161000000001, -161.40089)...
# Searching for nearest city to lat long (47.11703000000001, 111.27639)...
# Searching for nearest city to lat long (87.21663000000001, -71.17679000000001)...
# Searching for nearest city to lat long (-13.032370000000002, 153.38097000000002)...
# Searching for nearest city to lat long (-79.19671000000001, 22.05478)...
# Searching for nearest city to lat long (11.02739, 145.36105)...
# Searching for nearest city to lat long (-25.062250000000002, 137.34113000000002)...
# Searching for nearest city to lat long (-60.14940000000001, 155.38595)...
# Searching for nearest city to lat long (38.094620000000006, 50.124500000000005)...
# Searching for nearest city to lat long (49.12201, -65.16185)...
# Searching for nearest city to lat long (-13.032370000000002, -61.15189000000001)...
# Searching for nearest city to lat long (47.11703000000001, -43.10707000000001)...
# Searching for nearest city to lat long (-74.18426000000001, -142.35358000000002)...
# Searching for nearest city to lat long (29.072210000000002, 157.39093000000003)...
# Searching for nearest city to lat long (76.18924000000001, 152.37848000000002)...
# Searching for nearest city to lat long (30.074700000000004, 95.23655000000001)...
# Searching for nearest city to lat long (-16.03984, -114.28386000000002)...
# Searching for nearest city to lat long (-21.052290000000003, -118.29382000000001)...
# Searching for nearest city to lat long (-55.136950000000006, -32.07968)...
# Searching for nearest city to lat long (68.16932000000001, -157.39093000000003)...
# Searching for nearest city to lat long (-80.1992, -29.072210000000002)...
# Searching for nearest city to lat long (-79.19671000000001, -63.156870000000005)...
# Searching for nearest city to lat long (54.134460000000004, 84.20916000000001)...
# Searching for nearest city to lat long (-31.07719, -81.20169000000001)...
# Searching for nearest city to lat long (-49.12201, -13.032370000000002)...
# Searching for nearest city to lat long (-50.124500000000005, -98.24402)...
# Searching for nearest city to lat long (12.029880000000002, -74.18426000000001)...
# Searching for nearest city to lat long (-50.124500000000005, -29.072210000000002)...
# Searching for nearest city to lat long (23.057270000000003, 96.23904000000002)...
# Searching for nearest city to lat long (36.08964, 124.30876)...
# Searching for nearest city to lat long (-4.00996, -162.40338000000003)...
# Searching for nearest city to lat long (6.014940000000001, -42.104580000000006)...
# Searching for nearest city to lat long (2.00498, 126.31374000000001)...
# Searching for nearest city to lat long (-86.21414000000001, 69.17181000000001)...
# Searching for nearest city to lat long (18.04482, 69.17181000000001)...
# Searching for nearest city to lat long (-70.1743, -80.1992)...
# Searching for nearest city to lat long (89.22161000000001, -166.41334)...
# Searching for nearest city to lat long (-61.15189000000001, -76.18924000000001)...
# Searching for nearest city to lat long (43.10707000000001, -104.25896000000002)...
# Searching for nearest city to lat long (-20.0498, -12.029880000000002)...
# Searching for nearest city to lat long (48.11952000000001, 150.3735)...
# Searching for nearest city to lat long (-80.1992, 45.11205)...
# Searching for nearest city to lat long (29.072210000000002, -35.08715)...
# Searching for nearest city to lat long (2.00498, 177.44073000000003)...
# Searching for nearest city to lat long (-78.19422, -27.067230000000002)...
# Searching for nearest city to lat long (-57.14193000000001, 170.4233)...
# Searching for nearest city to lat long (-42.104580000000006, -87.21663000000001)...
# Searching for nearest city to lat long (59.146910000000005, 58.144420000000004)...
# Searching for nearest city to lat long (46.114540000000005, -131.32619000000003)...
# Searching for nearest city to lat long (-9.02241, 137.34113000000002)...
# Searching for nearest city to lat long (57.14193000000001, -121.30129000000001)...
# Searching for nearest city to lat long (75.18675, 87.21663000000001)...
# Searching for nearest city to lat long (-36.08964, 29.072210000000002)...
# Searching for nearest city to lat long (76.18924000000001, 93.23157)...
# Searching for nearest city to lat long (-26.064740000000004, -39.09711)...
# Searching for nearest city to lat long (-59.146910000000005, 79.19671000000001)...
# Searching for nearest city to lat long (11.02739, 46.114540000000005)...
# Searching for nearest city to lat long (-20.0498, 116.28884000000001)...
# Searching for nearest city to lat long (-89.22161000000001, 137.34113000000002)...
# Searching for nearest city to lat long (-45.11205, -8.01992)...
# Searching for nearest city to lat long (-35.08715, 77.19173)...
# Searching for nearest city to lat long (59.146910000000005, 51.126990000000006)...
# Searching for nearest city to lat long (-78.19422, 60.14940000000001)...
# Searching for nearest city to lat long (71.17679000000001, -165.41085)...
# Searching for nearest city to lat long (70.1743, -19.047310000000003)...
# Searching for nearest city to lat long (-4.00996, 112.27888000000002)...
# Searching for nearest city to lat long (25.062250000000002, 109.27141000000002)...
# Searching for nearest city to lat long (3.0074700000000005, -67.16683)...
# Searching for nearest city to lat long (29.072210000000002, 172.42828000000003)...
# Searching for nearest city to lat long (6.014940000000001, -114.28386000000002)...
# Searching for nearest city to lat long (-86.21414000000001, 12.029880000000002)...
# Searching for nearest city to lat long (10.0249, 38.094620000000006)...
# Searching for nearest city to lat long (57.14193000000001, -62.15438)...
# Searching for nearest city to lat long (55.136950000000006, 156.38844)...
# Searching for nearest city to lat long (-65.16185, -166.41334)...
# Searching for nearest city to lat long (-27.067230000000002, -46.114540000000005)...
# Searching for nearest city to lat long (-73.18177000000001, -176.43824)...
# Searching for nearest city to lat long (-21.052290000000003, 73.18177000000001)...
# Searching for nearest city to lat long (5.01245, 144.35856)...
# Searching for nearest city to lat long (-56.13944000000001, -80.1992)...
# Searching for nearest city to lat long (-47.11703000000001, -151.37599)...
# Searching for nearest city to lat long (75.18675, 128.31872)...
# Searching for nearest city to lat long (35.08715, 48.11952000000001)...
# Searching for nearest city to lat long (65.16185, -11.02739)...
# Searching for nearest city to lat long (26.064740000000004, 157.39093000000003)...
# Searching for nearest city to lat long (-19.047310000000003, -153.38097000000002)...
# Searching for nearest city to lat long (54.134460000000004, 109.27141000000002)...
# Searching for nearest city to lat long (-4.00996, 1.00249)...
# Searching for nearest city to lat long (-62.15438, -145.36105)...
# Searching for nearest city to lat long (21.052290000000003, -128.31872)...
# Searching for nearest city to lat long (38.094620000000006, -18.04482)...
# Searching for nearest city to lat long (-28.069720000000004, 49.12201)...
# Searching for nearest city to lat long (44.10956, 51.126990000000006)...
# Searching for nearest city to lat long (-34.08466000000001, 141.35109000000003)...
# Searching for nearest city to lat long (-80.1992, -152.37848000000002)...
# Searching for nearest city to lat long (-43.10707000000001, 172.42828000000003)...
# Searching for nearest city to lat long (-87.21663000000001, 135.33615)...
# Searching for nearest city to lat long (-55.136950000000006, -71.17679000000001)...
# Searching for nearest city to lat long (13.032370000000002, 164.40836000000002)...
# Searching for nearest city to lat long (-22.05478, 132.32868000000002)...
# Searching for nearest city to lat long (-72.17928, -73.18177000000001)...
# Searching for nearest city to lat long (57.14193000000001, 171.42579)...
# Searching for nearest city to lat long (-49.12201, 1.00249)...
# Searching for nearest city to lat long (34.08466000000001, 114.28386000000002)...
# Searching for nearest city to lat long (-25.062250000000002, -22.05478)...
# Searching for nearest city to lat long (65.16185, -29.072210000000002)...
# Searching for nearest city to lat long (-23.057270000000003, -47.11703000000001)...
# Searching for nearest city to lat long (52.12948000000001, 141.35109000000003)...
# Searching for nearest city to lat long (-23.057270000000003, -16.03984)...
# Searching for nearest city to lat long (-8.01992, 99.24651000000001)...
# Searching for nearest city to lat long (-49.12201, 84.20916000000001)...
# Searching for nearest city to lat long (-49.12201, -109.27141000000002)...
# Searching for nearest city to lat long (-76.18924000000001, -65.16185)...
# Searching for nearest city to lat long (-30.074700000000004, -155.38595)...
# Searching for nearest city to lat long (73.18177000000001, 9.02241)...
# Searching for nearest city to lat long (-10.0249, -80.1992)...
# Searching for nearest city to lat long (-57.14193000000001, 117.29133000000002)...
# Searching for nearest city to lat long (-27.067230000000002, 0.0)...
# Searching for nearest city to lat long (-49.12201, -139.34611)...
# Searching for nearest city to lat long (-24.059760000000004, -175.43575)...
# Searching for nearest city to lat long (51.126990000000006, -49.12201)...
# Searching for nearest city to lat long (68.16932000000001, -38.094620000000006)...
# Searching for nearest city to lat long (74.18426000000001, -115.28635000000001)...
# Searching for nearest city to lat long (57.14193000000001, -107.26643000000001)...
# Searching for nearest city to lat long (28.069720000000004, 121.30129000000001)...
# Searching for nearest city to lat long (81.20169000000001, 108.26892000000001)...
# Searching for nearest city to lat long (-16.03984, -54.134460000000004)...
# Searching for nearest city to lat long (19.047310000000003, 147.36603000000002)...
# Searching for nearest city to lat long (-60.14940000000001, -48.11952000000001)...
# Searching for nearest city to lat long (-78.19422, -61.15189000000001)...
# Searching for nearest city to lat long (81.20169000000001, 121.30129000000001)...
# Searching for nearest city to lat long (-53.13197, 74.18426000000001)...
# Searching for nearest city to lat long (-74.18426000000001, -114.28386000000002)...
# Searching for nearest city to lat long (44.10956, -160.3984)...
# Searching for nearest city to lat long (10.0249, -43.10707000000001)...
# Searching for nearest city to lat long (-66.16434000000001, -5.01245)...
# Searching for nearest city to lat long (-45.11205, 122.30378000000002)...
# Searching for nearest city to lat long (65.16185, 20.0498)...
# Searching for nearest city to lat long (-11.02739, 116.28884000000001)...
# Searching for nearest city to lat long (-36.08964, -6.014940000000001)...
# Searching for nearest city to lat long (85.21165, -134.33366)...
# Searching for nearest city to lat long (-29.072210000000002, -106.26394)...
# Searching for nearest city to lat long (32.07968, -31.07719)...
# Searching for nearest city to lat long (62.15438, 1.00249)...
# Searching for nearest city to lat long (2.00498, 72.17928)...
# Searching for nearest city to lat long (-56.13944000000001, 6.014940000000001)...
# Searching for nearest city to lat long (38.094620000000006, 154.38346)...
# Searching for nearest city to lat long (-52.12948000000001, 119.29631)...
# Searching for nearest city to lat long (27.067230000000002, -139.34611)...
# Searching for nearest city to lat long (-52.12948000000001, 150.3735)...
# Searching for nearest city to lat long (37.092130000000004, -20.0498)...
# Searching for nearest city to lat long (-85.21165, -44.10956)...
# Searching for nearest city to lat long (15.037350000000002, -126.31374000000001)...
# Searching for nearest city to lat long (50.124500000000005, 111.27639)...
# Searching for nearest city to lat long (72.17928, -31.07719)...
# Searching for nearest city to lat long (-71.17679000000001, -93.23157)...
# Searching for nearest city to lat long (-58.144420000000004, 146.36354000000003)...
# Searching for nearest city to lat long (49.12201, 146.36354000000003)...
# Searching for nearest city to lat long (-68.16932000000001, 103.25647000000001)...
# Searching for nearest city to lat long (79.19671000000001, -157.39093000000003)...
# Searching for nearest city to lat long (39.09711, -106.26394)...
# Searching for nearest city to lat long (27.067230000000002, 65.16185)...
# Searching for nearest city to lat long (19.047310000000003, -75.18675)...
# Searching for nearest city to lat long (-28.069720000000004, 133.33117000000001)...
# Searching for nearest city to lat long (7.017430000000001, 127.31623000000002)...
# Searching for nearest city to lat long (71.17679000000001, -78.19422)...
# Searching for nearest city to lat long (62.15438, -64.15936)...
# Searching for nearest city to lat long (-1.00249, -10.0249)...
# Searching for nearest city to lat long (33.082170000000005, -83.20667)...
# Searching for nearest city to lat long (-43.10707000000001, 147.36603000000002)...
# Searching for nearest city to lat long (-61.15189000000001, 37.092130000000004)...
# Searching for nearest city to lat long (87.21663000000001, -63.156870000000005)...
# Searching for nearest city to lat long (-25.062250000000002, -136.33864000000003)...
# Searching for nearest city to lat long (-25.062250000000002, -72.17928)...
# Searching for nearest city to lat long (-4.00996, 31.07719)...
# Searching for nearest city to lat long (-17.042330000000003, -124.30876)...
# Searching for nearest city to lat long (0.0, 7.017430000000001)...
# Searching for nearest city to lat long (76.18924000000001, -37.092130000000004)...
# Searching for nearest city to lat long (-73.18177000000001, -41.102090000000004)...
# Searching for nearest city to lat long (12.029880000000002, -40.0996)...
# Searching for nearest city to lat long (15.037350000000002, -85.21165)...
# Searching for nearest city to lat long (-44.10956, -122.30378000000002)...
# Searching for nearest city to lat long (81.20169000000001, -165.41085)...
# Searching for nearest city to lat long (16.03984, -129.32121)...
# Searching for nearest city to lat long (89.22161000000001, -154.38346)...
# Searching for nearest city to lat long (88.21912, -100.24900000000001)...
# Searching for nearest city to lat long (59.146910000000005, 91.22659000000002)...
# Searching for nearest city to lat long (-86.21414000000001, -64.15936)...
# Searching for nearest city to lat long (-66.16434000000001, -43.10707000000001)...
# Searching for nearest city to lat long (-32.07968, 67.16683)...
# Searching for nearest city to lat long (32.07968, 125.31125000000002)...
# Searching for nearest city to lat long (-74.18426000000001, 26.064740000000004)...
# Searching for nearest city to lat long (34.08466000000001, 64.15936)...
# Searching for nearest city to lat long (-20.0498, -87.21663000000001)...
# Searching for nearest city to lat long (-8.01992, 136.33864000000003)...
# Searching for nearest city to lat long (-70.1743, -18.04482)...
# Searching for nearest city to lat long (-17.042330000000003, -94.23406000000001)...
# Searching for nearest city to lat long (-32.07968, -87.21663000000001)...
# Searching for nearest city to lat long (42.104580000000006, 5.01245)...
# Searching for nearest city to lat long (-35.08715, -64.15936)...
# Searching for nearest city to lat long (69.17181000000001, -99.24651000000001)...
# Searching for nearest city to lat long (-38.094620000000006, 154.38346)...
# Searching for nearest city to lat long (-68.16932000000001, -25.062250000000002)...
# Searching for nearest city to lat long (-80.1992, -115.28635000000001)...
# Searching for nearest city to lat long (70.1743, -91.22659000000002)...
# Searching for nearest city to lat long (38.094620000000006, 142.35358000000002)...
# Searching for nearest city to lat long (-21.052290000000003, 63.156870000000005)...
# Searching for nearest city to lat long (-41.102090000000004, -36.08964)...
# Searching for nearest city to lat long (-8.01992, -146.36354000000003)...
# Searching for nearest city to lat long (47.11703000000001, 38.094620000000006)...
# Searching for nearest city to lat long (-38.094620000000006, 19.047310000000003)...
# Searching for nearest city to lat long (-4.00996, -102.25398000000001)...
# Searching for nearest city to lat long (-7.017430000000001, 45.11205)...
# Searching for nearest city to lat long (-54.134460000000004, 46.114540000000005)...
# Searching for nearest city to lat long (-29.072210000000002, 111.27639)...
# Searching for nearest city to lat long (-72.17928, -80.1992)...
# Searching for nearest city to lat long (-70.1743, 53.13197)...
# Searching for nearest city to lat long (18.04482, -165.41085)...
# Searching for nearest city to lat long (74.18426000000001, 108.26892000000001)...
# Searching for nearest city to lat long (-4.00996, -26.064740000000004)...
# Searching for nearest city to lat long (-86.21414000000001, -81.20169000000001)...
# Searching for nearest city to lat long (8.01992, -95.23655000000001)...
# Searching for nearest city to lat long (-59.146910000000005, 119.29631)...
# Searching for nearest city to lat long (-30.074700000000004, 18.04482)...
# Searching for nearest city to lat long (5.01245, 94.23406000000001)...
# Searching for nearest city to lat long (84.20916000000001, -153.38097000000002)...
# Searching for nearest city to lat long (-52.12948000000001, 131.32619000000003)...
# Searching for nearest city to lat long (25.062250000000002, 8.01992)...
# Searching for nearest city to lat long (59.146910000000005, 50.124500000000005)...
# Searching for nearest city to lat long (81.20169000000001, -72.17928)...
# Searching for nearest city to lat long (-72.17928, 114.28386000000002)...
# Searching for nearest city to lat long (-29.072210000000002, -1.00249)...
# Searching for nearest city to lat long (-2.00498, 7.017430000000001)...
# Searching for nearest city to lat long (-75.18675, 157.39093000000003)...
# Searching for nearest city to lat long (-11.02739, -69.17181000000001)...
# Searching for nearest city to lat long (77.19173, 89.22161000000001)...
# Searching for nearest city to lat long (8.01992, 164.40836000000002)...
# Searching for nearest city to lat long (-70.1743, 78.19422)...
# Searching for nearest city to lat long (85.21165, -9.02241)...
# Searching for nearest city to lat long (-77.19173, 99.24651000000001)...
# Searching for nearest city to lat long (13.032370000000002, 35.08715)...
# Searching for nearest city to lat long (29.072210000000002, 10.0249)...
# Searching for nearest city to lat long (-57.14193000000001, 79.19671000000001)...
# Searching for nearest city to lat long (74.18426000000001, -16.03984)...
# Searching for nearest city to lat long (42.104580000000006, -130.3237)...
# Searching for nearest city to lat long (-31.07719, 138.34362000000002)...
# Searching for nearest city to lat long (79.19671000000001, 153.38097000000002)...
# Searching for nearest city to lat long (-1.00249, -47.11703000000001)...
# Searching for nearest city to lat long (66.16434000000001, -47.11703000000001)...
# Searching for nearest city to lat long (10.0249, -72.17928)...
# Searching for nearest city to lat long (69.17181000000001, -70.1743)...
# Searching for nearest city to lat long (75.18675, -146.36354000000003)...
# Searching for nearest city to lat long (-89.22161000000001, 81.20169000000001)...
# Searching for nearest city to lat long (20.0498, -178.44322000000003)...
# Searching for nearest city to lat long (-45.11205, -18.04482)...
# Searching for nearest city to lat long (66.16434000000001, -124.30876)...
# Searching for nearest city to lat long (-35.08715, -26.064740000000004)...
# Searching for nearest city to lat long (-20.0498, 30.074700000000004)...
# Searching for nearest city to lat long (42.104580000000006, 114.28386000000002)...
# Searching for nearest city to lat long (55.136950000000006, -51.126990000000006)...
# Searching for nearest city to lat long (-15.037350000000002, 18.04482)...
# Searching for nearest city to lat long (-85.21165, -174.43326000000002)...
# Searching for nearest city to lat long (80.1992, 62.15438)...
# Searching for nearest city to lat long (89.22161000000001, -27.067230000000002)...
# Searching for nearest city to lat long (-13.032370000000002, 23.057270000000003)...
# Searching for nearest city to lat long (-50.124500000000005, -179.44571000000002)...
# Searching for nearest city to lat long (-45.11205, 144.35856)...
# Searching for nearest city to lat long (57.14193000000001, 3.0074700000000005)...
# Searching for nearest city to lat long (-80.1992, -88.21912)...
# Searching for nearest city to lat long (-25.062250000000002, 50.124500000000005)...
# Searching for nearest city to lat long (-19.047310000000003, 173.43077000000002)...
# Searching for nearest city to lat long (-73.18177000000001, -105.26145000000001)...
# Searching for nearest city to lat long (-23.057270000000003, -121.30129000000001)...
# Searching for nearest city to lat long (6.014940000000001, 55.136950000000006)...
# Searching for nearest city to lat long (-89.22161000000001, 58.144420000000004)...
# Searching for nearest city to lat long (-75.18675, 55.136950000000006)...
# Searching for nearest city to lat long (-13.032370000000002, 133.33117000000001)...
# Searching for nearest city to lat long (-53.13197, -40.0996)...
# Searching for nearest city to lat long (44.10956, -57.14193000000001)...
# Searching for nearest city to lat long (-25.062250000000002, 15.037350000000002)...
# Searching for nearest city to lat long (71.17679000000001, 81.20169000000001)...
# Searching for nearest city to lat long (30.074700000000004, 168.41832000000002)...
# Searching for nearest city to lat long (-73.18177000000001, 23.057270000000003)...
# Searching for nearest city to lat long (-49.12201, 35.08715)...
# Searching for nearest city to lat long (25.062250000000002, 61.15189000000001)...
# Searching for nearest city to lat long (-1.00249, 93.23157)...
# Searching for nearest city to lat long (60.14940000000001, 126.31374000000001)...
# Searching for nearest city to lat long (69.17181000000001, -7.017430000000001)...
# Searching for nearest city to lat long (-78.19422, 92.22908000000001)...
# Searching for nearest city to lat long (-41.102090000000004, -45.11205)...
# Searching for nearest city to lat long (-26.064740000000004, -166.41334)...
# Searching for nearest city to lat long (42.104580000000006, 26.064740000000004)...
# Searching for nearest city to lat long (-57.14193000000001, 59.146910000000005)...
# Searching for nearest city to lat long (-51.126990000000006, 103.25647000000001)...
# Searching for nearest city to lat long (-35.08715, -32.07968)...
# Searching for nearest city to lat long (-2.00498, -82.20418000000001)...
# Searching for nearest city to lat long (-69.17181000000001, 161.40089)...
# Searching for nearest city to lat long (7.017430000000001, -16.03984)...
# Searching for nearest city to lat long (24.059760000000004, 147.36603000000002)...
# Searching for nearest city to lat long (-83.20667, -83.20667)...
# Searching for nearest city to lat long (-26.064740000000004, -161.40089)...
# Searching for nearest city to lat long (48.11952000000001, 155.38595)...
# Searching for nearest city to lat long (-77.19173, -56.13944000000001)...
# Searching for nearest city to lat long (-73.18177000000001, -158.39342000000002)...
# Searching for nearest city to lat long (47.11703000000001, -166.41334)...
# Searching for nearest city to lat long (-73.18177000000001, -91.22659000000002)...
# Searching for nearest city to lat long (79.19671000000001, 75.18675)...
# Searching for nearest city to lat long (-67.16683, 112.27888000000002)...
# Searching for nearest city to lat long (-31.07719, -121.30129000000001)...
# Searching for nearest city to lat long (-40.0996, -141.35109000000003)...
# Searching for nearest city to lat long (44.10956, 90.2241)...
# Searching for nearest city to lat long (-12.029880000000002, -93.23157)...
# Searching for nearest city to lat long (-67.16683, -49.12201)...
# Searching for nearest city to lat long (-9.02241, -144.35856)...
# Searching for nearest city to lat long (-37.092130000000004, -11.02739)...
# Searching for nearest city to lat long (58.144420000000004, -87.21663000000001)...
# Searching for nearest city to lat long (72.17928, 98.24402)...
# Searching for nearest city to lat long (24.059760000000004, -24.059760000000004)...
# Searching for nearest city to lat long (59.146910000000005, 56.13944000000001)...
# Searching for nearest city to lat long (-26.064740000000004, -13.032370000000002)...
# Searching for nearest city to lat long (56.13944000000001, 88.21912)...
# Searching for nearest city to lat long (-62.15438, 92.22908000000001)...
# Searching for nearest city to lat long (84.20916000000001, 19.047310000000003)...
# Searching for nearest city to lat long (-84.20916000000001, -29.072210000000002)...
# Searching for nearest city to lat long (83.20667, -102.25398000000001)...
# Searching for nearest city to lat long (-48.11952000000001, -126.31374000000001)...
# Searching for nearest city to lat long (-60.14940000000001, -123.30627000000001)...
# Searching for nearest city to lat long (60.14940000000001, -157.39093000000003)...
# Searching for nearest city to lat long (-69.17181000000001, -12.029880000000002)...
# Searching for nearest city to lat long (-73.18177000000001, 85.21165)...
# Searching for nearest city to lat long (54.134460000000004, 4.00996)...
# Searching for nearest city to lat long (-27.067230000000002, -148.36852000000002)...
# Searching for nearest city to lat long (-87.21663000000001, -173.43077000000002)...
# Searching for nearest city to lat long (66.16434000000001, -140.3486)...
# Searching for nearest city to lat long (-26.064740000000004, -57.14193000000001)...
# Searching for nearest city to lat long (53.13197, 154.38346)...
# Searching for nearest city to lat long (-8.01992, -177.44073000000003)...
# Searching for nearest city to lat long (-24.059760000000004, -171.42579)...
# Searching for nearest city to lat long (21.052290000000003, -88.21912)...
# Searching for nearest city to lat long (-71.17679000000001, 44.10956)...
# Searching for nearest city to lat long (6.014940000000001, -138.34362000000002)...
# Searching for nearest city to lat long (30.074700000000004, 78.19422)...
# Searching for nearest city to lat long (-29.072210000000002, 171.42579)...
# Searching for nearest city to lat long (-28.069720000000004, 166.41334)...
# Searching for nearest city to lat long (20.0498, 11.02739)...
# Searching for nearest city to lat long (71.17679000000001, 67.16683)...
# Searching for nearest city to lat long (64.15936, -20.0498)...
# Searching for nearest city to lat long (-19.047310000000003, 4.00996)...
# Searching for nearest city to lat long (20.0498, -76.18924000000001)...
# Searching for nearest city to lat long (83.20667, 146.36354000000003)...
# Searching for nearest city to lat long (45.11205, 12.029880000000002)...
# Searching for nearest city to lat long (70.1743, -114.28386000000002)...
# Searching for nearest city to lat long (65.16185, 149.37101)...
# Searching for nearest city to lat long (7.017430000000001, 35.08715)...
# Searching for nearest city to lat long (-85.21165, -16.03984)...
# Searching for nearest city to lat long (-88.21912, 43.10707000000001)...
# Searching for nearest city to lat long (78.19422, 29.072210000000002)...
# Searching for nearest city to lat long (-86.21414000000001, -2.00498)...
# Searching for nearest city to lat long (19.047310000000003, 48.11952000000001)...
# Searching for nearest city to lat long (72.17928, -40.0996)...
# Searching for nearest city to lat long (23.057270000000003, 117.29133000000002)...
# Searching for nearest city to lat long (16.03984, 30.074700000000004)...
# Searching for nearest city to lat long (-11.02739, 102.25398000000001)...
# Searching for nearest city to lat long (12.029880000000002, -23.057270000000003)...
# Searching for nearest city to lat long (-15.037350000000002, -72.17928)...
# Searching for nearest city to lat long (-24.059760000000004, 51.126990000000006)...
# Searching for nearest city to lat long (81.20169000000001, -93.23157)...
# Searching for nearest city to lat long (-51.126990000000006, -80.1992)...
# Searching for nearest city to lat long (10.0249, -102.25398000000001)...
# Searching for nearest city to lat long (-4.00996, 88.21912)...
# Searching for nearest city to lat long (9.02241, -137.34113000000002)...
# Searching for nearest city to lat long (-64.15936, 70.1743)...
# Searching for nearest city to lat long (-58.144420000000004, -68.16932000000001)...
# Searching for nearest city to lat long (67.16683, -71.17679000000001)...
# Searching for nearest city to lat long (-58.144420000000004, -117.29133000000002)...
# Searching for nearest city to lat long (1.00249, -165.41085)...
# Searching for nearest city to lat long (-54.134460000000004, -68.16932000000001)...
# Searching for nearest city to lat long (24.059760000000004, -92.22908000000001)...
# Searching for nearest city to lat long (-69.17181000000001, -106.26394)...
# Searching for nearest city to lat long (35.08715, -81.20169000000001)...
# Searching for nearest city to lat long (57.14193000000001, 95.23655000000001)...
# Searching for nearest city to lat long (-31.07719, 150.3735)...
# Searching for nearest city to lat long (-76.18924000000001, -108.26892000000001)...
# Searching for nearest city to lat long (-64.15936, 29.072210000000002)...
# Searching for nearest city to lat long (-85.21165, 152.37848000000002)...
# Searching for nearest city to lat long (69.17181000000001, -136.33864000000003)...
# Searching for nearest city to lat long (-52.12948000000001, 125.31125000000002)...
# Searching for nearest city to lat long (-42.104580000000006, -108.26892000000001)...
# Searching for nearest city to lat long (6.014940000000001, 97.24153000000001)...
# Searching for nearest city to lat long (-13.032370000000002, -32.07968)...
# Searching for nearest city to lat long (-14.034860000000002, -167.41583000000003)...
# Searching for nearest city to lat long (-25.062250000000002, 26.064740000000004)...
# Searching for nearest city to lat long (85.21165, -15.037350000000002)...
# Searching for nearest city to lat long (73.18177000000001, -137.34113000000002)...
# Searching for nearest city to lat long (-36.08964, 151.37599)...
# Searching for nearest city to lat long (16.03984, 165.41085)...
# Searching for nearest city to lat long (-22.05478, -76.18924000000001)...
# Searching for nearest city to lat long (-37.092130000000004, 127.31623000000002)...
# Searching for nearest city to lat long (42.104580000000006, 91.22659000000002)...
# Searching for nearest city to lat long (-14.034860000000002, -64.15936)...
# Searching for nearest city to lat long (-5.01245, 136.33864000000003)...
# Searching for nearest city to lat long (-9.02241, 74.18426000000001)...
# Searching for nearest city to lat long (-59.146910000000005, 40.0996)...
# Searching for nearest city to lat long (31.07719, -1.00249)...
# Searching for nearest city to lat long (54.134460000000004, -167.41583000000003)...
# Searching for nearest city to lat long (5.01245, -1.00249)...
# Searching for nearest city to lat long (49.12201, -78.19422)...
# Searching for nearest city to lat long (86.21414000000001, 122.30378000000002)...
# Searching for nearest city to lat long (49.12201, 67.16683)...
# Searching for nearest city to lat long (-12.029880000000002, -88.21912)...
# Searching for nearest city to lat long (51.126990000000006, -33.082170000000005)...
# Searching for nearest city to lat long (51.126990000000006, -140.3486)...
# Searching for nearest city to lat long (7.017430000000001, 125.31125000000002)...
# Searching for nearest city to lat long (15.037350000000002, 58.144420000000004)...
# Searching for nearest city to lat long (89.22161000000001, 83.20667)...
# Searching for nearest city to lat long (-28.069720000000004, -40.0996)...
# Searching for nearest city to lat long (11.02739, -125.31125000000002)...
# Searching for nearest city to lat long (56.13944000000001, -24.059760000000004)...
# Searching for nearest city to lat long (0.0, -119.29631)...
# Searching for nearest city to lat long (25.062250000000002, -163.40587000000002)...
# Searching for nearest city to lat long (14.034860000000002, -72.17928)...
# Searching for nearest city to lat long (-81.20169000000001, 57.14193000000001)...
# Searching for nearest city to lat long (61.15189000000001, 89.22161000000001)...
# Searching for nearest city to lat long (-18.04482, -53.13197)...
# Searching for nearest city to lat long (-33.082170000000005, 47.11703000000001)...
# Searching for nearest city to lat long (88.21912, -61.15189000000001)...
# Searching for nearest city to lat long (-70.1743, 54.134460000000004)...
# Searching for nearest city to lat long (-19.047310000000003, 97.24153000000001)...
# Searching for nearest city to lat long (-3.0074700000000005, -179.44571000000002)...
# Searching for nearest city to lat long (10.0249, -97.24153000000001)...
# Searching for nearest city to lat long (-56.13944000000001, 55.136950000000006)...
# Searching for nearest city to lat long (-54.134460000000004, 46.114540000000005)...
# Searching for nearest city to lat long (77.19173, -19.047310000000003)...
# Searching for nearest city to lat long (-62.15438, -138.34362000000002)...
# Searching for nearest city to lat long (20.0498, 41.102090000000004)...
# Searching for nearest city to lat long (-65.16185, 112.27888000000002)...
# Searching for nearest city to lat long (38.094620000000006, -50.124500000000005)...
# Searching for nearest city to lat long (-22.05478, 60.14940000000001)...
# Searching for nearest city to lat long (-36.08964, -43.10707000000001)...
# Searching for nearest city to lat long (59.146910000000005, 17.042330000000003)...
# Searching for nearest city to lat long (-78.19422, -32.07968)...
# Searching for nearest city to lat long (37.092130000000004, 162.40338000000003)...
# Searching for nearest city to lat long (19.047310000000003, 111.27639)...
# Searching for nearest city to lat long (26.064740000000004, 144.35856)...
# Searching for nearest city to lat long (-57.14193000000001, 162.40338000000003)...
# Searching for nearest city to lat long (74.18426000000001, 178.44322000000003)...
# Searching for nearest city to lat long (63.156870000000005, 104.25896000000002)...
# Searching for nearest city to lat long (25.062250000000002, 92.22908000000001)...
# Searching for nearest city to lat long (54.134460000000004, 56.13944000000001)...
# Searching for nearest city to lat long (2.00498, 17.042330000000003)...
# Searching for nearest city to lat long (21.052290000000003, -74.18426000000001)...
# Searching for nearest city to lat long (57.14193000000001, -69.17181000000001)...
# Searching for nearest city to lat long (-79.19671000000001, 102.25398000000001)...
# Searching for nearest city to lat long (69.17181000000001, 165.41085)...
# Searching for nearest city to lat long (40.0996, 43.10707000000001)...
# Searching for nearest city to lat long (-87.21663000000001, 104.25896000000002)...
# Searching for nearest city to lat long (-13.032370000000002, -179.44571000000002)...
# Searching for nearest city to lat long (-21.052290000000003, 94.23406000000001)...
# Searching for nearest city to lat long (20.0498, 145.36105)...
# Searching for nearest city to lat long (-84.20916000000001, 33.082170000000005)...
# Searching for nearest city to lat long (-76.18924000000001, -100.24900000000001)...
# Searching for nearest city to lat long (58.144420000000004, -178.44322000000003)...
# Searching for nearest city to lat long (68.16932000000001, -35.08715)...
# Searching for nearest city to lat long (-36.08964, -75.18675)...
# Searching for nearest city to lat long (52.12948000000001, 38.094620000000006)...
# Searching for nearest city to lat long (-20.0498, 88.21912)...
# Searching for nearest city to lat long (-17.042330000000003, 178.44322000000003)...
# Searching for nearest city to lat long (-47.11703000000001, 62.15438)...
# Searching for nearest city to lat long (-81.20169000000001, -111.27639)...
# Searching for nearest city to lat long (-23.057270000000003, -55.136950000000006)...
# Searching for nearest city to lat long (-88.21912, 179.44571000000002)...
# Searching for nearest city to lat long (-56.13944000000001, 21.052290000000003)...
# Searching for nearest city to lat long (-77.19173, 66.16434000000001)...
# Searching for nearest city to lat long (-32.07968, -6.014940000000001)...
# Searching for nearest city to lat long (-32.07968, -56.13944000000001)...
# Searching for nearest city to lat long (31.07719, 32.07968)...
# Searching for nearest city to lat long (22.05478, -169.42081000000002)...
# Searching for nearest city to lat long (0.0, -159.39591000000001)...
# Searching for nearest city to lat long (78.19422, -143.35607000000002)...
# Searching for nearest city to lat long (-46.114540000000005, 169.42081000000002)...
# Searching for nearest city to lat long (84.20916000000001, -105.26145000000001)...
# Searching for nearest city to lat long (-14.034860000000002, 53.13197)...
# Searching for nearest city to lat long (70.1743, -172.42828000000003)...
# Searching for nearest city to lat long (41.102090000000004, 106.26394)...
# Searching for nearest city to lat long (-26.064740000000004, 175.43575)...
# Searching for nearest city to lat long (-87.21663000000001, 37.092130000000004)...
# Searching for nearest city to lat long (67.16683, -42.104580000000006)...
# Searching for nearest city to lat long (18.04482, 104.25896000000002)...
# Searching for nearest city to lat long (-84.20916000000001, -29.072210000000002)...
# Searching for nearest city to lat long (10.0249, 132.32868000000002)...
# Searching for nearest city to lat long (54.134460000000004, 138.34362000000002)...
# Searching for nearest city to lat long (-74.18426000000001, 74.18426000000001)...
# Searching for nearest city to lat long (2.00498, 177.44073000000003)...
# Searching for nearest city to lat long (40.0996, -147.36603000000002)...
# ...
# Searching for nearest city to lat long (31.07719, -60.14940000000001)...
# Searching for nearest city to lat long (-21.052290000000003, -149.37101)...
# Searching for nearest city to lat long (72.17928, 68.16932000000001)...
# Searching for nearest city to lat long (-12.029880000000002, -105.26145000000001)...
# Searching for nearest city to lat long (-61.15189000000001, 70.1743)...
# Searching for nearest city to lat long (64.15936, -97.24153000000001)...
# Searching for nearest city to lat long (-59.146910000000005, -150.3735)...
# Searching for nearest city to lat long (-9.02241, 113.28137000000001)...
# Searching for nearest city to lat long (58.144420000000004, -165.41085)...
# Searching for nearest city to lat long (-63.156870000000005, 172.42828000000003)...
# Searching for nearest city to lat long (-65.16185, -88.21912)...
# Searching for nearest city to lat long (11.02739, 167.41583000000003)...
# Searching for nearest city to lat long (-35.08715, -62.15438)...
# Searching for nearest city to lat long (0.0, -8.01992)...
# Searching for nearest city to lat long (-12.029880000000002, 113.28137000000001)...
# Searching for nearest city to lat long (-14.034860000000002, 103.25647000000001)...
# Searching for nearest city to lat long (40.0996, -151.37599)...
# Searching for nearest city to lat long (-59.146910000000005, 75.18675)...
# Searching for nearest city to lat long (65.16185, 0.0)...
# Searching for nearest city to lat long (-49.12201, 62.15438)...
# Searching for nearest city to lat long (-85.21165, 29.072210000000002)...
# Searching for nearest city to lat long (-33.082170000000005, 156.38844)...
# Searching for nearest city to lat long (-62.15438, 155.38595)...
# Searching for nearest city to lat long (-35.08715, -137.34113000000002)...
# Searching for nearest city to lat long (21.052290000000003, 147.36603000000002)...
# Searching for nearest city to lat long (60.14940000000001, -59.146910000000005)...
# Searching for nearest city to lat long (-30.074700000000004, -49.12201)...
# Searching for nearest city to lat long (85.21165, 162.40338000000003)...
# Searching for nearest city to lat long (83.20667, 11.02739)...
# Searching for nearest city to lat long (-62.15438, 10.0249)...
# Searching for nearest city to lat long (52.12948000000001, -104.25896000000002)...
# Searching for nearest city to lat long (-71.17679000000001, -12.029880000000002)...
# Searching for nearest city to lat long (22.05478, -60.14940000000001)...
# Searching for nearest city to lat long (-18.04482, 158.39342000000002)...
# Searching for nearest city to lat long (-44.10956, -27.067230000000002)...
# Searching for nearest city to lat long (32.07968, -77.19173)...
# Searching for nearest city to lat long (-76.18924000000001, -34.08466000000001)...
# Searching for nearest city to lat long (17.042330000000003, -20.0498)...
# Searching for nearest city to lat long (-87.21663000000001, 46.114540000000005)...
# Searching for nearest city to lat long (48.11952000000001, -134.33366)...
# Searching for nearest city to lat long (-33.082170000000005, -77.19173)...
# Searching for nearest city to lat long (76.18924000000001, 39.09711)...
# Searching for nearest city to lat long (78.19422, 175.43575)...
# Searching for nearest city to lat long (53.13197, -53.13197)...
# Searching for nearest city to lat long (-9.02241, 154.38346)...
# Searching for nearest city to lat long (57.14193000000001, -169.42081000000002)...
# Searching for nearest city to lat long (-10.0249, -87.21663000000001)...
# Searching for nearest city to lat long (-47.11703000000001, 120.29880000000001)...
# Searching for nearest city to lat long (-27.067230000000002, -172.42828000000003)...
# Searching for nearest city to lat long (38.094620000000006, -80.1992)...
# Searching for nearest city to lat long (-73.18177000000001, 59.146910000000005)...
# Searching for nearest city to lat long (38.094620000000006, -73.18177000000001)...
# Searching for nearest city to lat long (-34.08466000000001, -25.062250000000002)...
# Searching for nearest city to lat long (-35.08715, -119.29631)...
# Searching for nearest city to lat long (-19.047310000000003, 173.43077000000002)...
# Searching for nearest city to lat long (37.092130000000004, -115.28635000000001)...
# Searching for nearest city to lat long (84.20916000000001, -118.29382000000001)...
# Searching for nearest city to lat long (-58.144420000000004, -17.042330000000003)...
# Searching for nearest city to lat long (52.12948000000001, -93.23157)...
# Searching for nearest city to lat long (55.136950000000006, 86.21414000000001)...
# Searching for nearest city to lat long (77.19173, -75.18675)...
# Searching for nearest city to lat long (-53.13197, -2.00498)...
# Searching for nearest city to lat long (47.11703000000001, -20.0498)...
# Searching for nearest city to lat long (58.144420000000004, 145.36105)...
# Searching for nearest city to lat long (11.02739, -120.29880000000001)...
# Searching for nearest city to lat long (-69.17181000000001, 140.3486)...
# Searching for nearest city to lat long (-21.052290000000003, -146.36354000000003)...
# Searching for nearest city to lat long (56.13944000000001, -2.00498)...
# Searching for nearest city to lat long (-76.18924000000001, -114.28386000000002)...
# Searching for nearest city to lat long (62.15438, 134.33366)...
# Searching for nearest city to lat long (-3.0074700000000005, -153.38097000000002)...
# Searching for nearest city to lat long (-73.18177000000001, -108.26892000000001)...
# Searching for nearest city to lat long (15.037350000000002, -18.04482)...
# Searching for nearest city to lat long (42.104580000000006, 62.15438)...
# Searching for nearest city to lat long (-46.114540000000005, 104.25896000000002)...
# Searching for nearest city to lat long (89.22161000000001, 151.37599)...
# Searching for nearest city to lat long (79.19671000000001, 1.00249)...
# Searching for nearest city to lat long (-8.01992, -122.30378000000002)...
# Searching for nearest city to lat long (-71.17679000000001, -69.17181000000001)...
# Searching for nearest city to lat long (-89.22161000000001, -66.16434000000001)...
# Searching for nearest city to lat long (51.126990000000006, -129.32121)...
# Searching for nearest city to lat long (4.00996, -122.30378000000002)...
# Searching for nearest city to lat long (-26.064740000000004, -103.25647000000001)...
# Searching for nearest city to lat long (-75.18675, 138.34362000000002)...
# Searching for nearest city to lat long (-86.21414000000001, 54.134460000000004)...
# Searching for nearest city to lat long (-6.014940000000001, -75.18675)...
# Searching for nearest city to lat long (15.037350000000002, -64.15936)...
# Searching for nearest city to lat long (19.047310000000003, -16.03984)...
# Searching for nearest city to lat long (-73.18177000000001, 46.114540000000005)...
# Searching for nearest city to lat long (25.062250000000002, 137.34113000000002)...
# Searching for nearest city to lat long (-14.034860000000002, -12.029880000000002)...
# Searching for nearest city to lat long (-39.09711, 72.17928)...
# Searching for nearest city to lat long (-27.067230000000002, -81.20169000000001)...
# Searching for nearest city to lat long (59.146910000000005, -109.27141000000002)...
# Searching for nearest city to lat long (-50.124500000000005, 25.062250000000002)...
# Searching for nearest city to lat long (20.0498, -109.27141000000002)...
# Searching for nearest city to lat long (0.0, 122.30378000000002)...
# Searching for nearest city to lat long (55.136950000000006, 80.1992)...
# Searching for nearest city to lat long (69.17181000000001, -86.21414000000001)...
# Searching for nearest city to lat long (-82.20418000000001, -15.037350000000002)...
# Searching for nearest city to lat long (-54.134460000000004, -91.22659000000002)...
# Searching for nearest city to lat long (82.20418000000001, 58.144420000000004)...
# Searching for nearest city to lat long (58.144420000000004, -167.41583000000003)...
# Searching for nearest city to lat long (1.00249, -17.042330000000003)...
# Searching for nearest city to lat long (67.16683, -163.40587000000002)...
# Searching for nearest city to lat long (-21.052290000000003, -56.13944000000001)...
# Searching for nearest city to lat long (68.16932000000001, 97.24153000000001)...
# Searching for nearest city to lat long (-54.134460000000004, 91.22659000000002)...
# Searching for nearest city to lat long (-59.146910000000005, 131.32619000000003)...
# Searching for nearest city to lat long (75.18675, -125.31125000000002)...
# Searching for nearest city to lat long (-85.21165, 19.047310000000003)...
# Searching for nearest city to lat long (50.124500000000005, -83.20667)...
# Searching for nearest city to lat long (15.037350000000002, 56.13944000000001)...
# Searching for nearest city to lat long (-55.136950000000006, -100.24900000000001)...
# Searching for nearest city to lat long (16.03984, 148.36852000000002)...
# Searching for nearest city to lat long (78.19422, -158.39342000000002)...
# Searching for nearest city to lat long (-81.20169000000001, -157.39093000000003)...
# Searching for nearest city to lat long (15.037350000000002, 145.36105)...
# Searching for nearest city to lat long (-10.0249, 0.0)...
# Searching for nearest city to lat long (-57.14193000000001, 148.36852000000002)...
# Searching for nearest city to lat long (2.00498, -39.09711)...
# Searching for nearest city to lat long (-13.032370000000002, 99.24651000000001)...
# Searching for nearest city to lat long (7.017430000000001, 100.24900000000001)...
# Searching for nearest city to lat long (30.074700000000004, -43.10707000000001)...
# Searching for nearest city to lat long (12.029880000000002, 146.36354000000003)...
# Searching for nearest city to lat long (36.08964, 53.13197)...
# Searching for nearest city to lat long (-72.17928, -50.124500000000005)...
# Searching for nearest city to lat long (-83.20667, -106.26394)...
# Searching for nearest city to lat long (4.00996, 65.16185)...
# Searching for nearest city to lat long (-29.072210000000002, 97.24153000000001)...
# Searching for nearest city to lat long (57.14193000000001, 96.23904000000002)...
# Searching for nearest city to lat long (28.069720000000004, -88.21912)...
# Searching for nearest city to lat long (-75.18675, -160.3984)...
# Searching for nearest city to lat long (71.17679000000001, -11.02739)...
# Searching for nearest city to lat long (71.17679000000001, -18.04482)...
# Searching for nearest city to lat long (-48.11952000000001, -36.08964)...
# Searching for nearest city to lat long (-52.12948000000001, -7.017430000000001)...
# Searching for nearest city to lat long (8.01992, 57.14193000000001)...
# Searching for nearest city to lat long (66.16434000000001, 112.27888000000002)...
# Searching for nearest city to lat long (41.102090000000004, -138.34362000000002)...
# Searching for nearest city to lat long (-2.00498, 166.41334)...
# Searching for nearest city to lat long (50.124500000000005, -75.18675)...
# Searching for nearest city to lat long (-71.17679000000001, -8.01992)...
# Searching for nearest city to lat long (-13.032370000000002, 82.20418000000001)...
# Searching for nearest city to lat long (17.042330000000003, -46.114540000000005)...
# Searching for nearest city to lat long (-5.01245, 47.11703000000001)...
# Searching for nearest city to lat long (32.07968, 99.24651000000001)...
# Searching for nearest city to lat long (84.20916000000001, 164.40836000000002)...
# Searching for nearest city to lat long (-44.10956, -90.2241)...
# Searching for nearest city to lat long (14.034860000000002, 171.42579)...
# Searching for nearest city to lat long (-46.114540000000005, 92.22908000000001)...
# Searching for nearest city to lat long (-27.067230000000002, 42.104580000000006)...
# Searching for nearest city to lat long (-67.16683, -120.29880000000001)...
# Searching for nearest city to lat long (-26.064740000000004, -119.29631)...
# Searching for nearest city to lat long (63.156870000000005, -68.16932000000001)...
# Searching for nearest city to lat long (37.092130000000004, 8.01992)...
# Searching for nearest city to lat long (-4.00996, -3.0074700000000005)...
# Searching for nearest city to lat long (23.057270000000003, -40.0996)...
# Searching for nearest city to lat long (22.05478, 136.33864000000003)...
# Searching for nearest city to lat long (19.047310000000003, 3.0074700000000005)...
# Searching for nearest city to lat long (34.08466000000001, -137.34113000000002)...
# Searching for nearest city to lat long (89.22161000000001, -84.20916000000001)...
# Searching for nearest city to lat long (2.00498, 30.074700000000004)...
# Searching for nearest city to lat long (44.10956, 41.102090000000004)...
# Searching for nearest city to lat long (-11.02739, -21.052290000000003)...
# Searching for nearest city to lat long (59.146910000000005, 15.037350000000002)...
# Searching for nearest city to lat long (-5.01245, 53.13197)...
# Searching for nearest city to lat long (-50.124500000000005, -99.24651000000001)...
# Searching for nearest city to lat long (-43.10707000000001, -34.08466000000001)...
# Searching for nearest city to lat long (-8.01992, -32.07968)...
# Searching for nearest city to lat long (0.0, 133.33117000000001)...
# Searching for nearest city to lat long (9.02241, -25.062250000000002)...
# Searching for nearest city to lat long (64.15936, 88.21912)...
# Searching for nearest city to lat long (2.00498, -126.31374000000001)...
# Searching for nearest city to lat long (82.20418000000001, -89.22161000000001)...
# Searching for nearest city to lat long (-2.00498, 86.21414000000001)...
# Searching for nearest city to lat long (18.04482, -27.067230000000002)...
# Searching for nearest city to lat long (-82.20418000000001, -27.067230000000002)...
# Searching for nearest city to lat long (31.07719, -91.22659000000002)...
# Searching for nearest city to lat long (-16.03984, 103.25647000000001)...
# Searching for nearest city to lat long (-35.08715, 12.029880000000002)...
# Searching for nearest city to lat long (-23.057270000000003, -169.42081000000002)...
# Searching for nearest city to lat long (-75.18675, 59.146910000000005)...
# Searching for nearest city to lat long (33.082170000000005, 56.13944000000001)...
# Searching for nearest city to lat long (55.136950000000006, -170.4233)...
# Searching for nearest city to lat long (66.16434000000001, 59.146910000000005)...
# Searching for nearest city to lat long (81.20169000000001, -32.07968)...
# Searching for nearest city to lat long (40.0996, 172.42828000000003)...
# Searching for nearest city to lat long (-18.04482, -168.41832000000002)...
# Searching for nearest city to lat long (-52.12948000000001, 110.27390000000001)...
# Searching for nearest city to lat long (57.14193000000001, -71.17679000000001)...
# Searching for nearest city to lat long (76.18924000000001, 27.067230000000002)...
# Searching for nearest city to lat long (54.134460000000004, 6.014940000000001)...
# Searching for nearest city to lat long (80.1992, 130.3237)...
# Searching for nearest city to lat long (83.20667, 5.01245)...
# Searching for nearest city to lat long (89.22161000000001, 105.26145000000001)...
# Searching for nearest city to lat long (81.20169000000001, 117.29133000000002)...
# Searching for nearest city to lat long (19.047310000000003, 2.00498)...
# Searching for nearest city to lat long (-42.104580000000006, 55.136950000000006)...
# Searching for nearest city to lat long (-26.064740000000004, -158.39342000000002)...
# Searching for nearest city to lat long (-84.20916000000001, 39.09711)...
# Searching for nearest city to lat long (86.21414000000001, 29.072210000000002)...
# Searching for nearest city to lat long (-1.00249, -101.25149)...
# ushuaia         49
# rikitea         46
# mataura         40
# punta arenas    32
# busselton       30
#                 ..
# veraval          1
# ranau            1
# pascagoula       1
# dhidhdhoo        1
# huautla          1
# Name: City_Name, Length: 610, dtype: int64
# 0              marzuq
# 1            victoria
# 2       saint anthony
# 3                auki
# 4                kaeo
#             ...
# 1468       turukhansk
# 1474          zachary
# 1479            tabas
# 1481             inta
# 1488     kollumerland
# Name: City_Name, Length: 610, dtype: object

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city = "London"
# Build partial query URL
base_url = url + "q=" + city + "&units=" + units + "&appid=" + api_key

# %%
# set up lists to hold reponse info
tempsList = []
humidityList = []
cloudinessList = []
windspeedsList = []
DateList = []
defective_cities = []

# Loop through the list of cities and perform a request for data on each
for city in cityList:
    print(f"Searching for city weather data for {city}...Onward and forward") 
    weather_url = url + "q=" + city + "&units=" + units + "&appid=" + api_key
    response = requests.get(weather_url).json()
    try:
        tempsList.append(response['main']['temp_max'])
        humidityList.append(response['main']['humidity'])
        cloudinessList.append(response['clouds']['all'])
        windspeedsList.append(response['wind']['speed'])
        DateList.append(response['dt'])
    except:
        print(f"Oops, looks like this city: {city} gave us a problem. On to the next one")
        defective_cities.append(city)
        tempsList.append('NaN')
        humidityList.append('NaN')
        cloudinessList.append('NaN')
        windspeedsList.append('NaN')
        DateList.append('NaN')

defective_cities
# Out:
# ['palabuhanratu',
#  'nizhneyansk',
#  'illoqqortoormiut',
#  'asayita',
#  'barentsburg',
#  'dujuma',
#  'jiddah',
#  'yirol',
#  'bargal',
#  'ondorhaan',
#  'samusu',
#  'taolanaro',
#  'rungata',
#  'fort saint john',
#  'grand river south east',
#  'sentyabrskiy',
#  'sahrak',
#  'amderma',
#  'jabiru',
#  'karaul',
#  'attawapiskat',
#  'vaitupu',
#  'saleaula',
#  'satitoa',
#  'tsihombe',
#  'karakose',
#  'halalo',
#  'haibowan',
#  'meyungs',
#  'belushya guba',
#  'mys shmidta',
#  'paradwip',
#  'bolungarvik',
#  'chagda',
#  'gardan diwal',
#  'galiwinku',
#  'sofiysk',
#  'acuna',
#  'sedelnikovo',
#  'ust-kamchatsk',
#  'tumannyy',
#  'grand centre',
#  'tabiauea',
#  'bur gabo',
#  'tabarqah',
#  'kollumerland']

# %%
#  Make sure I have >= 500 cities
print(f"Cities list : {len(cityList)}")
# print(f"Latitudes list : {len(latlist)}")
# print(f"Longitudes list : {len(longlist)}")
# Out:
# Cities list : 610

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
dict_with_lists2 = {"City": cityList, 
                    "Latitude": LatList, 
                    "Longitude": LongList, 
                    "Max_Temp": tempsList, 
                    "Humidity": humidityList, 
                    "Cloudiness": cloudinessList, 
                    "Wind_Speed": windspeedsList, 
                    "Country_Code": countryList, 
                    "Date": DateList}
weather_data_500 = pd.DataFrame(dict_with_lists2)
weather_data_500 = weather_data_500.dropna(how='any')
weather_data_500 = weather_data_500[~weather_data_500.Max_Temp.str.contains("NaN", na=False)]
weather_data_500.head(100)

#  Making sure I have >= 500 cities
print(weather_data_500["City"].value_counts())
weather_data_500
# Out:
# pathein          1
# yaan             1
# alofi            1
# mount isa        1
# ust-kuyga        1
#                 ..
# yumen            1
# kaoma            1
# san quintin      1
# moose factory    1
# huautla          1
# Name: City, Length: 564, dtype: int64
#               City  Latitude  Longitude Max_Temp Humidity Cloudiness  \
# 0           marzuq  23.05727   15.03735    82.27       33          0
# 1         victoria  -4.00996   57.14193    87.01       82         94
# 2    saint anthony  55.13695  -55.13695     57.2       66          1
# 3             auki  -6.01494  163.40587    85.42       71        100
# 4             kaeo -26.06474  176.43824    66.99       48          0
# ..             ...       ...        ...      ...      ...        ...
# 604      manokwari   0.00000  133.33117    84.27       66         22
# 605     turukhansk  64.15936   88.21912    51.91       83         96
# 606        zachary  31.07719  -91.22659       77       88          1
# 607          tabas  33.08217   56.13944     71.6       30          0
# 608           inta  66.16434   59.14691       45       83        100
#
#     Wind_Speed Country_Code        Date
# 0         0.89           ly  1600315525
# 1         1.99           sc  1600315302
# 2         3.36           ca  1600315525
# 3         8.03           sb  1600315525
# 4         8.99           nz  1600315525
# ..         ...          ...         ...
# 604       4.18           id  1600315369
# 605       14.9           ru  1600315652
# 606       3.36           us  1600315652
# 607        4.7           ir  1600315652
# 608      14.58           ru  1600315653
#
# [564 rows x 9 columns]

# %%
# Create lists and dicts needed
Lat_City_Mean_List = []
Long_City_Mean_List = []
Temp_City_Mean_List = []
Hum_City_Mean_List = []
Cloud_City_Mean_List = []
Wind_City_Mean_List = []

# Populate the statistics list for the lat
Lat_City_Mean_List.append(len(weather_data_500["Latitude"]))
Lat_City_Mean_List.append(np.mean(weather_data_500["Latitude"]))
Lat_City_Mean_List.append(np.median(weather_data_500["Latitude"]))
Lat_City_Mean_List.append(np.std(weather_data_500["Latitude"]))
Lat_City_Mean_List.append(np.min(weather_data_500["Latitude"]))
Lat_City_Mean_List.append(np.max(weather_data_500["Latitude"]))
quartiles = weather_data_500["Latitude"].quantile([.25,.5,.75])
quartiles
latQ1 = quartiles[0.25]
latQ2 = quartiles[0.50]
latQ3 = quartiles[0.75]
Lat_City_Mean_List.append(latQ1)
Lat_City_Mean_List.append(latQ2)
Lat_City_Mean_List.append(latQ3)

# Populate the statistics list for the long
Long_City_Mean_List.append(len(weather_data_500["Longitude"]))
Long_City_Mean_List.append(np.mean(weather_data_500["Longitude"]))
Long_City_Mean_List.append(np.median(weather_data_500["Longitude"]))
Long_City_Mean_List.append(np.std(weather_data_500["Longitude"]))
Long_City_Mean_List.append(np.min(weather_data_500["Longitude"]))
Long_City_Mean_List.append(np.max(weather_data_500["Longitude"]))
quartiles = weather_data_500["Longitude"].quantile([.25,.5,.75])
quartiles
lngQ1 = quartiles[0.25]
lngQ2 = quartiles[0.50]
lngQ3 = quartiles[0.75]
Long_City_Mean_List.append(lngQ1)
Long_City_Mean_List.append(lngQ2)
Long_City_Mean_List.append(lngQ3)

# Populate the statistics list for the temperatures
Temp_City_Mean_List.append(len(weather_data_500["Max_Temp"]))
Temp_City_Mean_List.append(np.mean(weather_data_500["Max_Temp"]))
Temp_City_Mean_List.append(np.median(weather_data_500["Max_Temp"]))
Temp_City_Mean_List.append(np.std(weather_data_500["Max_Temp"]))
Temp_City_Mean_List.append(np.min(weather_data_500["Max_Temp"]))
Temp_City_Mean_List.append(np.max(weather_data_500["Max_Temp"]))
quartiles = weather_data_500["Max_Temp"].quantile([.25,.5,.75])
quartiles
tempQ1 = quartiles[0.25]
tempQ2 = quartiles[0.50]
tempQ3 = quartiles[0.75]
Temp_City_Mean_List.append(tempQ1)
Temp_City_Mean_List.append(tempQ2)
Temp_City_Mean_List.append(tempQ3)

# Populate the statistics list for the humidities
Hum_City_Mean_List.append(len(weather_data_500["Humidity"]))
Hum_City_Mean_List.append(np.mean(weather_data_500["Humidity"]))
Hum_City_Mean_List.append(np.median(weather_data_500["Humidity"]))
Hum_City_Mean_List.append(np.std(weather_data_500["Humidity"]))
Hum_City_Mean_List.append(np.min(weather_data_500["Humidity"]))
Hum_City_Mean_List.append(np.max(weather_data_500["Humidity"]))
quartiles = weather_data_500["Humidity"].quantile([.25,.5,.75])
quartiles
humQ1 = quartiles[0.25]
humQ2 = quartiles[0.50]
humQ3 = quartiles[0.75]
Hum_City_Mean_List.append(humQ1)
Hum_City_Mean_List.append(humQ2)
Hum_City_Mean_List.append(humQ3)

# Populate the statistics list for the cloudiness
Cloud_City_Mean_List.append(len(weather_data_500["Cloudiness"]))
Cloud_City_Mean_List.append(np.mean(weather_data_500["Cloudiness"]))
Cloud_City_Mean_List.append(np.median(weather_data_500["Cloudiness"]))
Cloud_City_Mean_List.append(np.std(weather_data_500["Cloudiness"]))
Cloud_City_Mean_List.append(np.min(weather_data_500["Cloudiness"]))
Cloud_City_Mean_List.append(np.max(weather_data_500["Cloudiness"]))
quartiles = weather_data_500["Cloudiness"].quantile([.25,.5,.75])
quartiles
cldQ1 = quartiles[0.25]
cldQ2 = quartiles[0.50]
cldQ3 = quartiles[0.75]
Cloud_City_Mean_List.append(cldQ1)
Cloud_City_Mean_List.append(cldQ2)
Cloud_City_Mean_List.append(cldQ3)

# Populate the statistics list for the wind speed
Wind_City_Mean_List.append(len(weather_data_500["Wind_Speed"]))
Wind_City_Mean_List.append(np.mean(weather_data_500["Wind_Speed"]))
Wind_City_Mean_List.append(np.median(weather_data_500["Wind_Speed"]))
Wind_City_Mean_List.append(np.std(weather_data_500["Wind_Speed"]))
Wind_City_Mean_List.append(np.min(weather_data_500["Wind_Speed"]))
Wind_City_Mean_List.append(np.max(weather_data_500["Wind_Speed"]))
quartiles = weather_data_500["Wind_Speed"].quantile([.25,.5,.75])
quartiles
wspdQ1 = quartiles[0.25]
wspdQ2 = quartiles[0.50]
wspdQ3 = quartiles[0.75]
Wind_City_Mean_List.append(wspdQ1)
Wind_City_Mean_List.append(wspdQ2)
Wind_City_Mean_List.append(wspdQ3)

IndexList = ['Count', 'Mean', 'Median', 'std', 'min', 'max', '25%', '50%', '75%']
# Create and display a summary stats dataframe from calculate values
summary_stats_dict= {"index": IndexList, "Latitude": Lat_City_Mean_List, "Longitude": Long_City_Mean_List, "Max_Temp": Temp_City_Mean_List, 
                     "Humidity": Hum_City_Mean_List, "Cloudiness": Cloud_City_Mean_List, "Wind_Speed": Wind_City_Mean_List}

summary_stats_df = pd.DataFrame(summary_stats_dict)
summary_stats_df
# Out:
#     index    Latitude   Longitude    Max_Temp    Humidity  Cloudiness  \
# 0   Count  564.000000  564.000000  564.000000  564.000000  564.000000
# 1    Mean   16.884136   16.880581   65.800887   71.671986   51.338652
# 2  Median   19.047310   22.054780   67.690000   77.000000   56.000000
# 3     std   37.593137   92.286697   15.204058   20.717122   39.783241
# 4     min  -88.219120 -178.443220   16.560000    8.000000    0.000000
# 5     max   88.219120  179.445710   96.800000  100.000000  100.000000
# 6     25%  -11.027390  -63.156870   54.932500   61.750000    5.000000
# 7     50%   19.047310   22.054780   67.690000   77.000000   56.000000
# 8     75%   48.370143   96.239040   78.010000   87.000000   90.000000
#
#    Wind_Speed
# 0  564.000000
# 1    8.171099
# 2    6.930000
# 3    5.596277
# 4    0.130000
# 5   39.150000
# 6    3.590000
# 7    6.930000
# 8   11.410000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
# To remove cities with Humidity > 100%
print(f"Minimum humidity value: {weather_data_500['Humidity'].min()}")
print(f"Maximum humidity value: {weather_data_500['Humidity'].max()}")
# weather_data_500_hum100 = weather_data_500[weather_data_500.Humidity<=100]
# weather_data_500_hum100['Humidity'].max()
# Out:
# Minimum humidity value: 8
# Maximum humidity value: 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
humIQR = humQ3 - humQ1
humlower_bound = humQ1 - (1.5*humIQR)
humupper_bound = humQ3 + (1.5*humIQR)
clean_city_data_df = weather_data_500.loc[(weather_data_500["Humidity"]>= humlower_bound) & (weather_data_500["Humidity"]<= humupper_bound)]

# QC statements
print(f"Inter Quartile Range is: {humIQR}")
print(f"Lower bound is: {humlower_bound}")
print(f"Upper bound is: {humupper_bound}")
print(f"Minimum humidity value of clean city data: {clean_city_data_df['Humidity'].min()}")
print(f"Maximum humidity value of clean city data: {clean_city_data_df['Humidity'].max()}")
clean_city_data_df
# Out:
# Inter Quartile Range is: 25.25
# Lower bound is: 23.875
# Upper bound is: 124.875
# Minimum humidity value of clean city data: 24
# Maximum humidity value of clean city data: 100
#               City  Latitude  Longitude Max_Temp Humidity Cloudiness  \
# 0           marzuq  23.05727   15.03735    82.27       33          0
# 1         victoria  -4.00996   57.14193    87.01       82         94
# 2    saint anthony  55.13695  -55.13695     57.2       66          1
# 3             auki  -6.01494  163.40587    85.42       71        100
# 4             kaeo -26.06474  176.43824    66.99       48          0
# ..             ...       ...        ...      ...      ...        ...
# 604      manokwari   0.00000  133.33117    84.27       66         22
# 605     turukhansk  64.15936   88.21912    51.91       83         96
# 606        zachary  31.07719  -91.22659       77       88          1
# 607          tabas  33.08217   56.13944     71.6       30          0
# 608           inta  66.16434   59.14691       45       83        100
#
#     Wind_Speed Country_Code        Date
# 0         0.89           ly  1600315525
# 1         1.99           sc  1600315302
# 2         3.36           ca  1600315525
# 3         8.03           sb  1600315525
# 4         8.99           nz  1600315525
# ..         ...          ...         ...
# 604       4.18           id  1600315369
# 605       14.9           ru  1600315652
# 606       3.36           us  1600315652
# 607        4.7           ir  1600315652
# 608      14.58           ru  1600315653
#
# [544 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generate a series for the needed columns from dataframe
ScatPlot_MaxTemps = clean_city_data_df['Max_Temp']
ScatPlot_Lat = clean_city_data_df['Latitude']

# Make lists out of the columns
List_a = ScatPlot_MaxTemps.values.tolist()
List_b = ScatPlot_Lat.values.tolist()

# Create a dataframe for plot
Listsab = {"Max_Temp": List_a,
           "Latitude": List_b}
LatTemp_ScatPlot_df = pd.DataFrame(Listsab)
LatTemp_ScatPlot_df

# Create plot
LatTemp_ScatPlot_df.plot(kind='scatter', x="Latitude", y="Max_Temp", marker="o", edgecolors="blue", alpha=0.8, figsize=(10,8))
plt.title("City Latitude vs. Max_Temps")
plt.xlabel("City Latitude")
plt.ylabel("Max_Temps (F)")
plt.xlim(-90, 90)
plt.ylim(0, (LatTemp_ScatPlot_df['Max_Temp'].max()+5))
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Temps.png"))
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generate a series for the needed columns from dataframe
ScatPlot_Hum = clean_city_data_df['Humidity']
ScatPlot_Lat = clean_city_data_df['Latitude']

# Make lists out of the columns
List_a = ScatPlot_Hum.values.tolist()
List_b = ScatPlot_Lat.values.tolist()

# Create a dataframe for plot
Listsab = {"Humidity": List_a,
           "Latitude": List_b}
LatHum_ScatPlot_df = pd.DataFrame(Listsab)
LatHum_ScatPlot_df

# Create plot
LatHum_ScatPlot_df.plot(kind='scatter', x="Latitude", y="Humidity", marker="o", edgecolors="blue", alpha=0.8, figsize=(10,8))
plt.title("City Latitude vs. Humidity")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-90, 90)
plt.ylim(0, 105)
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Humidity.png"))
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generate a series for the needed columns from dataframe
ScatPlot_Cloud = clean_city_data_df['Cloudiness']
ScatPlot_Lat = clean_city_data_df['Latitude']

# Make lists out of the columns
List_a = ScatPlot_Cloud.values.tolist()
List_b = ScatPlot_Lat.values.tolist()

# Create a dataframe for plot
Listsab = {"Cloudiness": List_a,
           "Latitude": List_b}
LatCloud_ScatPlot_df = pd.DataFrame(Listsab)
LatCloud_ScatPlot_df

# Create plot
LatCloud_ScatPlot_df.plot(kind='scatter', x="Latitude", y="Cloudiness", marker="o", edgecolors="blue", alpha=0.8, figsize=(10,8))
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(-90, 90)
plt.ylim(0, 105)
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Cloudiness.png"))
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generate a series for the needed columns from dataframe
ScatPlot_Wind_Speed = clean_city_data_df['Wind_Speed']
ScatPlot_Lat = clean_city_data_df['Latitude']

# Make lists out of the columns
List_a = ScatPlot_Wind_Speed.values.tolist()
List_b = ScatPlot_Lat.values.tolist()

# Create a dataframe for plot
Listsab = {"Wind_Speed": List_a,
           "Latitude": List_b}
LatWind_Speed_ScatPlot_df = pd.DataFrame(Listsab)
LatWind_Speed_ScatPlot_df
LatWind_Speed_ScatPlot_df['Wind_Speed'].max()

# Create plot
LatWind_Speed_ScatPlot_df.plot(kind='scatter', x="Latitude", y="Wind_Speed", marker="o", edgecolors="blue", alpha=0.8, figsize=(10,8))
plt.title("City Latitude vs. Wind_Speed")
plt.xlabel("City Latitude")
plt.ylabel("Wind_Speed (mph)")
plt.xlim(-90, 90)
plt.ylim(0,(LatWind_Speed_ScatPlot_df['Wind_Speed'].max()+1.5))
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Windspeed.png"))
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatTemp_ScatPlot_df
NorthHem_LatTemp_ScatPlot_df = LatTemp_ScatPlot_df[LatTemp_ScatPlot_df.Latitude>=0]
print(f"The count for cities in the Northern Hemisphere is: {NorthHem_LatTemp_ScatPlot_df['Latitude'].count()}")

#  CORRELATION COEFFICIENT
MaxTemp = NorthHem_LatTemp_ScatPlot_df['Max_Temp']
Latitude = NorthHem_LatTemp_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, MaxTemp)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {(correlation[1])}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, MaxTemp)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, MaxTemp)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.annotate(line_eq, (60,20), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.xlim(0, 90)
plt.ylim(0, (LatTemp_ScatPlot_df['Max_Temp'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_MaxTemp_NorthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The count for cities in the Northern Hemisphere is: 364
# The correlation coefficient (r) is -0.8053
# The p-value is 3.401340099686781e-84
# The r-value is: 0.6485

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatTemp_ScatPlot_df
SouthHem_LatTemp_ScatPlot_df = LatTemp_ScatPlot_df[LatTemp_ScatPlot_df.Latitude<=0]
print(f"The count for cities in the Southern Hemisphere is: {SouthHem_LatTemp_ScatPlot_df['Latitude'].count()}")

#  CORRELATION COEFFICIENT
MaxTemp = SouthHem_LatTemp_ScatPlot_df['Max_Temp']
Latitude = SouthHem_LatTemp_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, MaxTemp)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {round(correlation[1],20)}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, MaxTemp)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, MaxTemp)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.annotate(line_eq, (-80,38), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.xlim(-90, 0)
plt.ylim(0, (LatTemp_ScatPlot_df['Max_Temp'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_MaxTemp_SouthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The count for cities in the Southern Hemisphere is: 187
# The correlation coefficient (r) is 0.6083
# The p-value is 3e-20
# The r-value is: 0.37

# %% [markdown]
# ### Observations from Max_Temp vs. Latitude (Northern and Southern Hemisphere)
#  - There is a strong trend in both the Northern and southern hemisphere data (Stronger with the Northern hemisphere data). R-value of 0.64 for Northern Hemisphere and 0.37 for Southern hemisphere . Temperature drop as you get further away from the equator.
#  - Many more data points (cities) in the Northern hemisphere (364 cities) and Southern hemisphere (187 cities). This observation is the true for every plot pair and so will not be repeated each time.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatHum_ScatPlot_df
NorthHem_LatHum_ScatPlot_df = LatHum_ScatPlot_df[LatHum_ScatPlot_df.Latitude>=0]

#  CORRELATION COEFFICIENT
Humidity = NorthHem_LatHum_ScatPlot_df['Humidity']
Latitude = NorthHem_LatHum_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, Humidity)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {round(correlation[1],20)}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, Humidity)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, Humidity)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.annotate(line_eq, (60,38), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim((NorthHem_LatHum_ScatPlot_df['Latitude'].min()-1), (NorthHem_LatHum_ScatPlot_df['Latitude'].max()+1))
plt.ylim(0, (LatHum_ScatPlot_df['Humidity'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Humidity_NorthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The correlation coefficient (r) is 0.026
# The p-value is 0.620749480360141
# The r-value is: 0.0007

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatHum_ScatPlot_df
SouthHem_LatHum_ScatPlot_df = LatHum_ScatPlot_df[LatHum_ScatPlot_df.Latitude<=0]

#  CORRELATION COEFFICIENT
Humidity = SouthHem_LatHum_ScatPlot_df['Humidity']
Latitude = SouthHem_LatHum_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, Humidity)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {(correlation[1])}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, Humidity)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, Humidity)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.annotate(line_eq, (-80,60), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim((SouthHem_LatHum_ScatPlot_df['Latitude'].min()-1), (SouthHem_LatHum_ScatPlot_df['Latitude'].max()+1))
plt.ylim(0, (LatHum_ScatPlot_df['Humidity'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Humidity_SouthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The correlation coefficient (r) is -0.031
# The p-value is 0.6732100320994775
# The r-value is: 0.001

# %% [markdown]
# ### Observations from Humidity vs. Latitude (Northern and Southern Hemisphere)
#  - There is no discernable trend with the data in the Northern or Southern hemisphere data . R-value of 0.0007 for Northern Hemisphere and 0.001 for Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatCloud_ScatPlot_df
NorthHem_LatCloud_ScatPlot_df = LatCloud_ScatPlot_df[LatCloud_ScatPlot_df.Latitude>=0]

#  CORRELATION COEFFICIENT
Cloud = NorthHem_LatCloud_ScatPlot_df['Cloudiness']
Latitude = NorthHem_LatCloud_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, Cloud)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {(correlation[1])}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(Latitude, Cloud)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, Cloud)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.annotate(line_eq, (60,60), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim((NorthHem_LatCloud_ScatPlot_df['Latitude'].min()-1), (NorthHem_LatCloud_ScatPlot_df['Latitude'].max()+1))
plt.ylim(0, (NorthHem_LatCloud_ScatPlot_df['Cloudiness'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Cloudiness_NorthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The correlation coefficient (r) is 0.1062
# The p-value is 0.042889255142691665
# The r-value is: 0.0113

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatCloud_ScatPlot_df
SouthHem_LatCloud_ScatPlot_df = LatCloud_ScatPlot_df[LatCloud_ScatPlot_df.Latitude<=0]

#  CORRELATION COEFFICIENT
Cloud = SouthHem_LatCloud_ScatPlot_df['Cloudiness']
Latitude = SouthHem_LatCloud_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, Cloud)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {(correlation[1])}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(Latitude, Cloud)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, Cloud)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.annotate(line_eq, (-80,34), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim((SouthHem_LatCloud_ScatPlot_df['Latitude'].min()-1), (SouthHem_LatCloud_ScatPlot_df['Latitude'].max()+1))
plt.ylim(0, (SouthHem_LatCloud_ScatPlot_df['Cloudiness'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_Cloudiness_SouthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The correlation coefficient (r) is -0.0011
# The p-value is 0.9882748942379793
# The r-value is: 0.0

# %% [markdown]
# ### Observations from Cloudiness vs. Latitude (Northern and Southern Hemisphere)
#  - There is no discernable trend with the data in the Northern or Southern hemisphere data . R-value of 0.01 for Northern Hemisphere and 0.00 for Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatWind_Speed_ScatPlot_df
NorthHem_LatWind_Speed_ScatPlot_df = LatWind_Speed_ScatPlot_df[LatWind_Speed_ScatPlot_df.Latitude>=0]

#  CORRELATION COEFFICIENT
Wind = NorthHem_LatWind_Speed_ScatPlot_df['Wind_Speed']
Latitude = NorthHem_LatWind_Speed_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, Wind)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {(correlation[1])}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(Latitude, Wind)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, Wind)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Northern Hemisphere - Wind_Speed vs. Latitude Linear Regression")
plt.annotate(line_eq, (10,23), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind_Speed (mph)')
plt.xlim((NorthHem_LatWind_Speed_ScatPlot_df['Latitude'].min()-1), (NorthHem_LatWind_Speed_ScatPlot_df['Latitude'].max()+1))
plt.ylim(0, (NorthHem_LatWind_Speed_ScatPlot_df['Wind_Speed'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_WindSpeed_NorthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The correlation coefficient (r) is 0.2254
# The p-value is 1.41013319174052e-05
# The r-value is: 0.0508

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# dataframe from scatter plot
LatWind_Speed_ScatPlot_df
SouthHem_LatWind_Speed_ScatPlot_df = LatWind_Speed_ScatPlot_df[LatWind_Speed_ScatPlot_df.Latitude<=0]

#  CORRELATION COEFFICIENT
Wind = SouthHem_LatWind_Speed_ScatPlot_df['Wind_Speed']
Latitude = SouthHem_LatWind_Speed_ScatPlot_df['Latitude']
correlation = sts.pearsonr(Latitude, Wind)

print(f"The correlation coefficient (r) is {round(correlation[0],4)}")
print(f"The p-value is {(correlation[1])}")

#  LINEAR REGRESSION MODEL 
# Run the regression and store each of the returned values
slope, intercept, rvalue, pvalue, stderr = linregress(Latitude, Wind)

# Calculate the predictions for each value of x
regression_values = Latitude * slope + intercept

# store a string version of the linear equation, so we can display it on the plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.figure(figsize=(10,8))
plt.scatter(Latitude, Wind)

# Plot the regression line
plt.plot(Latitude, regression_values, "red")

# Annotate the plot with the linear equation
plt.title("Southern Hemisphere - Wind_Speed vs. Latitude Linear Regression")
plt.annotate(line_eq, (-80,16), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind_Speed (mph)')
plt.xlim((SouthHem_LatWind_Speed_ScatPlot_df['Latitude'].min()-1), (SouthHem_LatWind_Speed_ScatPlot_df['Latitude'].max()+1))
plt.ylim(0, (SouthHem_LatWind_Speed_ScatPlot_df['Wind_Speed'].max()+5))
print(f"The r-value is: {round(rvalue**2,4)}")
plt.grid(True)
plt.savefig(os.path.join("..","output_data","City_Latitude_vs_WindSpeed_SouthernHemisphere.png"))
plt.show()
plt.tight_layout()
# Out:
# The correlation coefficient (r) is -0.2231
# The p-value is 0.0021488068436206764
# The r-value is: 0.0498

# %% [markdown]
# ### Observations from Wind_Speed vs. Latitude (Northern and Southern Hemisphere)
#  - There is a somewhat weak trend in both the Northern and southern hemisphere data. R-value of 0.05 for Northern Hemisphere and 0.049 for Southern hemisphere . Wind speed drops as you get closer to the equator.

# %% [markdown]
# ####  Saving csv file

# %%
clean_city_data_df.to_csv('clean_city_data.csv', index = False) 
summary_stats_df.to_csv('summary_stats.csv', index = False) 
clean_city_data_df.to_csv('../output_data/clean_city_data.csv', index = False) 
summary_stats_df.to_csv('../output_data/summary_stats.csv', index = False)
